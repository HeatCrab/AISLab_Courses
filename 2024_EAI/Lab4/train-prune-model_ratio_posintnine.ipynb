# %% [markdown]
# ## Import library

# %%
from __future__ import print_function
import os
import argparse

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable

import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('/kaggle/input/vgg/pytorch/default/1')
from vgg import vgg

# %% [markdown]
# ## 設定超參數

# %%
TRAIN_BATCH_SIZE = 100
TEST_BATCH_SIZE = 1000
EPOCHS = 60
LEARNING_RATE = 0.1
MOMENTUM = 0.9
WEIGHT_DECAY = 1e-4
LOG_INTERVAL = 100
CUDA = True
SEED = 1

RESUME = True
START_EPOCH = 0


PRUNE_PATH = '/kaggle/input/vgg_prune/pytorch/ratio_pointnine/1/model_prune_ratio_0.9.pth'
# PRUNE_PATH = '/kaggle/input/vgg_prune/pytorch/ratio_pointfive/1/model_prune_ratio_0.5.pth'
PRUNE_FINETUNE_PATH = f'/kaggle/working/model_prune_finetune.pth'

# %% [markdown]
# #### 檢查是否檢查是否可使用GPU

# %%
if(torch.cuda.is_available()):
    CUDA = True
    kwargs = {'num_workers': 1, 'pin_memory': True}
    torch.cuda.manual_seed(SEED)
else:
    CUDA = False
    kwargs = {}

# %% [markdown]
# ## 下載資料集

# %% [markdown]
# 這裡將訓練集做Augmentation(Pad, RandCrop, Random)，測試集不用做Augmentation

# %%
#### DATASET ####
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.Pad(4),
                       transforms.RandomCrop(32),
                       transforms.RandomHorizontalFlip(),
                       transforms.ToTensor(),
                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                   ])),
    batch_size=TRAIN_BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('./data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                   ])),
    batch_size=TEST_BATCH_SIZE, shuffle=True, **kwargs)
# Out:
# 100%|██████████| 170M/170M [00:01<00:00, 93.0MB/s]

# %% [markdown]
# ## 載入剪枝後的網路與權重

# %%
model = None
if(RESUME):
  checkpoint = torch.load(PRUNE_PATH)
  model = vgg(cfg=checkpoint['cfg'])
  model.load_state_dict(checkpoint['state_dict'])

  print('RESUME PRUNE MODEL')

if CUDA:
    model.cuda()
# Out:
# RESUME PRUNE MODEL

# %% [markdown]
# ## 設定Optimizer，這裡使用Stocastic Gradient Descent with

# %%
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)

# %% [markdown]
# ## 定義訓練跟測試函數

# %%
#### 訓練函數 #####
# 訓練時的準確率紀錄
train_accuracies = []

def train(epoch):
    model.train()
    correct = 0
    total = 0

    for batch_idx, (data, target) in enumerate(train_loader):
        if CUDA:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()

        pred = output.data.max(1, keepdim=True)[1]  # get the index of the max log-probability
        correct += pred.eq(target.data.view_as(pred)).cpu().sum().item()
        total += target.size(0)

        if batch_idx % LOG_INTERVAL == 0:
            print('\nTrain Epoch: {} [{}/{} ({:.1f}%)]\tLoss: {:.6f}'.format(
                epoch+1, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

    # 紀錄當前˙epoch 的訓練準確率
    train_accuracy = 100. * correct / total
    train_accuracies.append(train_accuracy)
    print('Train Epoch: {}  Accuracy: {}/{} ({:.1f}%)'.format(
        epoch+1, correct, total, train_accuracy))

# %%
#### 測試函數 ####
def test():
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
      for data, target in test_loader:
          if CUDA:
              data, target = data.cuda(), target.cuda()
          data, target = Variable(data), Variable(target)
          output = model(data)
          test_loss += F.cross_entropy(output, target, reduction='sum').data.item()
          pred = output.data.max(1, keepdim=True)[1]
          correct += pred.eq(target.data.view_as(pred)).cpu().sum()

      test_loss /= len(test_loader.dataset)
      print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
          test_loss, correct, len(test_loader.dataset),
          100. * correct / len(test_loader.dataset)))
      return correct / float(len(test_loader.dataset))

# %%
best_prec1 = 0.
for epoch in range(START_EPOCH, EPOCHS):
    # Learning Rate在0.5EPOCHS與0.75EPOCHS調整為原本之十分之一
    if epoch in [EPOCHS*0.5, EPOCHS*0.75]:
        for param_group in optimizer.param_groups:
            param_group['lr'] *= 0.1
    train(epoch)
    prec1 = test()

    # 儲存模型權重，方便做後續剪枝,後續訓練
    if(prec1 > best_prec1):
        torch.save({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_prec1': best_prec1,
            'optimizer': optimizer.state_dict(),
        }, PRUNE_FINETUNE_PATH)

    best_prec1 = max(prec1, best_prec1)

print('\n TRAIN PRUNED MODEL DONE!')
# Out:
# Train Epoch: 1 [0/50000 (0.0%)]	Loss: 2.967023
#
# Train Epoch: 1 [10000/50000 (20.0%)]	Loss: 1.864847
#
# Train Epoch: 1 [20000/50000 (40.0%)]	Loss: 1.568660
#
# Train Epoch: 1 [30000/50000 (60.0%)]	Loss: 1.419894
#
# Train Epoch: 1 [40000/50000 (80.0%)]	Loss: 1.185120
# Train Epoch: 1  Accuracy: 19250/50000 (38.5%)
#
# Test set: Average loss: 1.2928, Accuracy: 5111/10000 (51.1%)
#
#
# Train Epoch: 2 [0/50000 (0.0%)]	Loss: 1.142043
#
# Train Epoch: 2 [10000/50000 (20.0%)]	Loss: 1.114506
#
# Train Epoch: 2 [20000/50000 (40.0%)]	Loss: 0.971198
#
# Train Epoch: 2 [30000/50000 (60.0%)]	Loss: 1.121193
#
# Train Epoch: 2 [40000/50000 (80.0%)]	Loss: 0.956621
# Train Epoch: 2  Accuracy: 31897/50000 (63.8%)
#
# Test set: Average loss: 1.1719, Accuracy: 6564/10000 (65.6%)
#
#
# Train Epoch: 3 [0/50000 (0.0%)]	Loss: 0.961237
#
# Train Epoch: 3 [10000/50000 (20.0%)]	Loss: 0.892008
#
# Train Epoch: 3 [20000/50000 (40.0%)]	Loss: 0.883854
#
# Train Epoch: 3 [30000/50000 (60.0%)]	Loss: 0.720494
#
# Train Epoch: 3 [40000/50000 (80.0%)]	Loss: 0.790384
# Train Epoch: 3  Accuracy: 35291/50000 (70.6%)
#
# Test set: Average loss: 1.0150, Accuracy: 6796/10000 (68.0%)
#
#
# Train Epoch: 4 [0/50000 (0.0%)]	Loss: 0.928243
#
# Train Epoch: 4 [10000/50000 (20.0%)]	Loss: 0.809316
#
# Train Epoch: 4 [20000/50000 (40.0%)]	Loss: 0.645095
#
# Train Epoch: 4 [30000/50000 (60.0%)]	Loss: 0.856622
#
# Train Epoch: 4 [40000/50000 (80.0%)]	Loss: 0.678979
# Train Epoch: 4  Accuracy: 36828/50000 (73.7%)
#
# Test set: Average loss: 0.9334, Accuracy: 6970/10000 (69.7%)
#
#
# Train Epoch: 5 [0/50000 (0.0%)]	Loss: 0.613860
#
# Train Epoch: 5 [10000/50000 (20.0%)]	Loss: 0.633408
#
# Train Epoch: 5 [20000/50000 (40.0%)]	Loss: 1.290464
#
# Train Epoch: 5 [30000/50000 (60.0%)]	Loss: 0.769203
#
# Train Epoch: 5 [40000/50000 (80.0%)]	Loss: 0.818734
# Train Epoch: 5  Accuracy: 37795/50000 (75.6%)
#
# Test set: Average loss: 0.8861, Accuracy: 7441/10000 (74.4%)
#
#
# Train Epoch: 6 [0/50000 (0.0%)]	Loss: 0.601852
#
# Train Epoch: 6 [10000/50000 (20.0%)]	Loss: 0.878951
#
# Train Epoch: 6 [20000/50000 (40.0%)]	Loss: 0.592732
#
# Train Epoch: 6 [30000/50000 (60.0%)]	Loss: 0.841819
#
# Train Epoch: 6 [40000/50000 (80.0%)]	Loss: 0.713491
# Train Epoch: 6  Accuracy: 39048/50000 (78.1%)
#
# Test set: Average loss: 1.5487, Accuracy: 4791/10000 (47.9%)
#
#
# Train Epoch: 7 [0/50000 (0.0%)]	Loss: 0.642904
#
# Train Epoch: 7 [10000/50000 (20.0%)]	Loss: 0.568439
#
# Train Epoch: 7 [20000/50000 (40.0%)]	Loss: 0.718889
#
# Train Epoch: 7 [30000/50000 (60.0%)]	Loss: 0.716914
#
# Train Epoch: 7 [40000/50000 (80.0%)]	Loss: 0.460801
# Train Epoch: 7  Accuracy: 40021/50000 (80.0%)
#
# Test set: Average loss: 0.9191, Accuracy: 7152/10000 (71.5%)
#
#
# Train Epoch: 8 [0/50000 (0.0%)]	Loss: 0.435347
#
# Train Epoch: 8 [10000/50000 (20.0%)]	Loss: 0.668048
#
# Train Epoch: 8 [20000/50000 (40.0%)]	Loss: 0.554712
#
# Train Epoch: 8 [30000/50000 (60.0%)]	Loss: 0.585580
#
# Train Epoch: 8 [40000/50000 (80.0%)]	Loss: 0.495235
# Train Epoch: 8  Accuracy: 40865/50000 (81.7%)
#
# Test set: Average loss: 0.9062, Accuracy: 7319/10000 (73.2%)
#
#
# Train Epoch: 9 [0/50000 (0.0%)]	Loss: 0.557810
#
# Train Epoch: 9 [10000/50000 (20.0%)]	Loss: 0.491022
#
# Train Epoch: 9 [20000/50000 (40.0%)]	Loss: 0.581466
#
# Train Epoch: 9 [30000/50000 (60.0%)]	Loss: 0.712991
#
# Train Epoch: 9 [40000/50000 (80.0%)]	Loss: 0.481205
# Train Epoch: 9  Accuracy: 41232/50000 (82.5%)
#
# Test set: Average loss: 0.6950, Accuracy: 7976/10000 (79.8%)
#
#
# Train Epoch: 10 [0/50000 (0.0%)]	Loss: 0.552875
#
# Train Epoch: 10 [10000/50000 (20.0%)]	Loss: 0.541366
#
# Train Epoch: 10 [20000/50000 (40.0%)]	Loss: 0.372777
#
# Train Epoch: 10 [30000/50000 (60.0%)]	Loss: 0.563754
#
# Train Epoch: 10 [40000/50000 (80.0%)]	Loss: 0.343613
# Train Epoch: 10  Accuracy: 41536/50000 (83.1%)
#
# Test set: Average loss: 0.6913, Accuracy: 7793/10000 (77.9%)
#
#
# Train Epoch: 11 [0/50000 (0.0%)]	Loss: 0.621486
#
# Train Epoch: 11 [10000/50000 (20.0%)]	Loss: 0.405666
#
# Train Epoch: 11 [20000/50000 (40.0%)]	Loss: 0.636187
#
# Train Epoch: 11 [30000/50000 (60.0%)]	Loss: 0.570183
#
# Train Epoch: 11 [40000/50000 (80.0%)]	Loss: 0.565375
# Train Epoch: 11  Accuracy: 41777/50000 (83.6%)
#
# Test set: Average loss: 0.6925, Accuracy: 7903/10000 (79.0%)
#
#
# Train Epoch: 12 [0/50000 (0.0%)]	Loss: 0.490534
#
# Train Epoch: 12 [10000/50000 (20.0%)]	Loss: 0.585873
#
# Train Epoch: 12 [20000/50000 (40.0%)]	Loss: 0.561067
#
# Train Epoch: 12 [30000/50000 (60.0%)]	Loss: 0.590735
#
# Train Epoch: 12 [40000/50000 (80.0%)]	Loss: 0.656283
# Train Epoch: 12  Accuracy: 42046/50000 (84.1%)
#
# Test set: Average loss: 0.5457, Accuracy: 8247/10000 (82.5%)
#
#
# Train Epoch: 13 [0/50000 (0.0%)]	Loss: 0.356636
#
# Train Epoch: 13 [10000/50000 (20.0%)]	Loss: 0.673119
#
# Train Epoch: 13 [20000/50000 (40.0%)]	Loss: 0.456100
#
# Train Epoch: 13 [30000/50000 (60.0%)]	Loss: 0.513126
#
# Train Epoch: 13 [40000/50000 (80.0%)]	Loss: 0.413532
# Train Epoch: 13  Accuracy: 42328/50000 (84.7%)
#
# Test set: Average loss: 0.7384, Accuracy: 7781/10000 (77.8%)
#
#
# Train Epoch: 14 [0/50000 (0.0%)]	Loss: 0.435984
#
# Train Epoch: 14 [10000/50000 (20.0%)]	Loss: 0.448236
#
# Train Epoch: 14 [20000/50000 (40.0%)]	Loss: 0.558602
#
# Train Epoch: 14 [30000/50000 (60.0%)]	Loss: 0.330403
#
# Train Epoch: 14 [40000/50000 (80.0%)]	Loss: 0.546678
# Train Epoch: 14  Accuracy: 42482/50000 (85.0%)
#
# Test set: Average loss: 1.2212, Accuracy: 6770/10000 (67.7%)
#
#
# Train Epoch: 15 [0/50000 (0.0%)]	Loss: 0.546790
#
# Train Epoch: 15 [10000/50000 (20.0%)]	Loss: 0.369796
#
# Train Epoch: 15 [20000/50000 (40.0%)]	Loss: 0.411481
#
# Train Epoch: 15 [30000/50000 (60.0%)]	Loss: 0.388181
#
# Train Epoch: 15 [40000/50000 (80.0%)]	Loss: 0.536506
# Train Epoch: 15  Accuracy: 42534/50000 (85.1%)
#
# Test set: Average loss: 0.5826, Accuracy: 8168/10000 (81.7%)
#
#
# Train Epoch: 16 [0/50000 (0.0%)]	Loss: 0.361215
#
# Train Epoch: 16 [10000/50000 (20.0%)]	Loss: 0.540183
#
# Train Epoch: 16 [20000/50000 (40.0%)]	Loss: 0.429009
#
# Train Epoch: 16 [30000/50000 (60.0%)]	Loss: 0.317519
#
# Train Epoch: 16 [40000/50000 (80.0%)]	Loss: 0.182261
# Train Epoch: 16  Accuracy: 42881/50000 (85.8%)
#
# Test set: Average loss: 0.6823, Accuracy: 7979/10000 (79.8%)
#
#
# Train Epoch: 17 [0/50000 (0.0%)]	Loss: 0.409999
#
# Train Epoch: 17 [10000/50000 (20.0%)]	Loss: 0.418973
#
# Train Epoch: 17 [20000/50000 (40.0%)]	Loss: 0.380032
#
# Train Epoch: 17 [30000/50000 (60.0%)]	Loss: 0.696077
#
# Train Epoch: 17 [40000/50000 (80.0%)]	Loss: 0.439647
# Train Epoch: 17  Accuracy: 42782/50000 (85.6%)
#
# Test set: Average loss: 0.5430, Accuracy: 8258/10000 (82.6%)
#
#
# Train Epoch: 18 [0/50000 (0.0%)]	Loss: 0.348804
#
# Train Epoch: 18 [10000/50000 (20.0%)]	Loss: 0.440494
#
# Train Epoch: 18 [20000/50000 (40.0%)]	Loss: 0.371639
#
# Train Epoch: 18 [30000/50000 (60.0%)]	Loss: 0.439319
#
# Train Epoch: 18 [40000/50000 (80.0%)]	Loss: 0.394712
# Train Epoch: 18  Accuracy: 42941/50000 (85.9%)
#
# Test set: Average loss: 0.7729, Accuracy: 7775/10000 (77.8%)
#
#
# Train Epoch: 19 [0/50000 (0.0%)]	Loss: 0.412833
#
# Train Epoch: 19 [10000/50000 (20.0%)]	Loss: 0.264326
#
# Train Epoch: 19 [20000/50000 (40.0%)]	Loss: 0.496170
#
# Train Epoch: 19 [30000/50000 (60.0%)]	Loss: 0.346294
#
# Train Epoch: 19 [40000/50000 (80.0%)]	Loss: 0.388700
# Train Epoch: 19  Accuracy: 43095/50000 (86.2%)
#
# Test set: Average loss: 0.7460, Accuracy: 7832/10000 (78.3%)
#
#
# Train Epoch: 20 [0/50000 (0.0%)]	Loss: 0.389973
#
# Train Epoch: 20 [10000/50000 (20.0%)]	Loss: 0.392262
#
# Train Epoch: 20 [20000/50000 (40.0%)]	Loss: 0.246577
#
# Train Epoch: 20 [30000/50000 (60.0%)]	Loss: 0.555934
#
# Train Epoch: 20 [40000/50000 (80.0%)]	Loss: 0.435865
# Train Epoch: 20  Accuracy: 43019/50000 (86.0%)
#
# Test set: Average loss: 0.5349, Accuracy: 8322/10000 (83.2%)
#
#
# Train Epoch: 21 [0/50000 (0.0%)]	Loss: 0.442298
#
# Train Epoch: 21 [10000/50000 (20.0%)]	Loss: 0.426272
#
# Train Epoch: 21 [20000/50000 (40.0%)]	Loss: 0.476894
#
# Train Epoch: 21 [30000/50000 (60.0%)]	Loss: 0.306187
#
# Train Epoch: 21 [40000/50000 (80.0%)]	Loss: 0.449393
# Train Epoch: 21  Accuracy: 43180/50000 (86.4%)
#
# Test set: Average loss: 0.5153, Accuracy: 8447/10000 (84.5%)
#
#
# Train Epoch: 22 [0/50000 (0.0%)]	Loss: 0.225576
#
# Train Epoch: 22 [10000/50000 (20.0%)]	Loss: 0.322870
#
# Train Epoch: 22 [20000/50000 (40.0%)]	Loss: 0.317819
#
# Train Epoch: 22 [30000/50000 (60.0%)]	Loss: 0.292255
#
# Train Epoch: 22 [40000/50000 (80.0%)]	Loss: 0.486832
# Train Epoch: 22  Accuracy: 43344/50000 (86.7%)
#
# Test set: Average loss: 0.6261, Accuracy: 8099/10000 (81.0%)
#
#
# Train Epoch: 23 [0/50000 (0.0%)]	Loss: 0.497619
#
# Train Epoch: 23 [10000/50000 (20.0%)]	Loss: 0.281353
#
# Train Epoch: 23 [20000/50000 (40.0%)]	Loss: 0.370998
#
# Train Epoch: 23 [30000/50000 (60.0%)]	Loss: 0.377785
#
# Train Epoch: 23 [40000/50000 (80.0%)]	Loss: 0.319868
# Train Epoch: 23  Accuracy: 43479/50000 (87.0%)
#
# Test set: Average loss: 0.6524, Accuracy: 7971/10000 (79.7%)
#
#
# Train Epoch: 24 [0/50000 (0.0%)]	Loss: 0.445899
#
# Train Epoch: 24 [10000/50000 (20.0%)]	Loss: 0.384273
#
# Train Epoch: 24 [20000/50000 (40.0%)]	Loss: 0.440809
#
# Train Epoch: 24 [30000/50000 (60.0%)]	Loss: 0.216579
#
# Train Epoch: 24 [40000/50000 (80.0%)]	Loss: 0.458642
# Train Epoch: 24  Accuracy: 43466/50000 (86.9%)
#
# Test set: Average loss: 0.6703, Accuracy: 7974/10000 (79.7%)
#
#
# Train Epoch: 25 [0/50000 (0.0%)]	Loss: 0.259298
#
# Train Epoch: 25 [10000/50000 (20.0%)]	Loss: 0.496382
#
# Train Epoch: 25 [20000/50000 (40.0%)]	Loss: 0.477959
#
# Train Epoch: 25 [30000/50000 (60.0%)]	Loss: 0.505734
#
# Train Epoch: 25 [40000/50000 (80.0%)]	Loss: 0.380114
# Train Epoch: 25  Accuracy: 43423/50000 (86.8%)
#
# Test set: Average loss: 0.7698, Accuracy: 7751/10000 (77.5%)
#
#
# Train Epoch: 26 [0/50000 (0.0%)]	Loss: 0.244463
#
# Train Epoch: 26 [10000/50000 (20.0%)]	Loss: 0.358861
#
# Train Epoch: 26 [20000/50000 (40.0%)]	Loss: 0.264134
#
# Train Epoch: 26 [30000/50000 (60.0%)]	Loss: 0.329957
#
# Train Epoch: 26 [40000/50000 (80.0%)]	Loss: 0.286685
# Train Epoch: 26  Accuracy: 43600/50000 (87.2%)
#
# Test set: Average loss: 0.6587, Accuracy: 7942/10000 (79.4%)
#
#
# Train Epoch: 27 [0/50000 (0.0%)]	Loss: 0.419019
#
# Train Epoch: 27 [10000/50000 (20.0%)]	Loss: 0.212504
#
# Train Epoch: 27 [20000/50000 (40.0%)]	Loss: 0.302277
#
# Train Epoch: 27 [30000/50000 (60.0%)]	Loss: 0.343283
#
# Train Epoch: 27 [40000/50000 (80.0%)]	Loss: 0.238765
# Train Epoch: 27  Accuracy: 43602/50000 (87.2%)
#
# Test set: Average loss: 0.5648, Accuracy: 8294/10000 (82.9%)
#
#
# Train Epoch: 28 [0/50000 (0.0%)]	Loss: 0.303319
#
# Train Epoch: 28 [10000/50000 (20.0%)]	Loss: 0.435044
#
# Train Epoch: 28 [20000/50000 (40.0%)]	Loss: 0.301083
#
# Train Epoch: 28 [30000/50000 (60.0%)]	Loss: 0.362657
#
# Train Epoch: 28 [40000/50000 (80.0%)]	Loss: 0.572186
# Train Epoch: 28  Accuracy: 43650/50000 (87.3%)
#
# Test set: Average loss: 0.5556, Accuracy: 8261/10000 (82.6%)
#
#
# Train Epoch: 29 [0/50000 (0.0%)]	Loss: 0.336509
#
# Train Epoch: 29 [10000/50000 (20.0%)]	Loss: 0.309899
#
# Train Epoch: 29 [20000/50000 (40.0%)]	Loss: 0.376560
#
# Train Epoch: 29 [30000/50000 (60.0%)]	Loss: 0.373039
#
# Train Epoch: 29 [40000/50000 (80.0%)]	Loss: 0.323157
# Train Epoch: 29  Accuracy: 43677/50000 (87.4%)
#
# Test set: Average loss: 0.5043, Accuracy: 8401/10000 (84.0%)
#
#
# Train Epoch: 30 [0/50000 (0.0%)]	Loss: 0.351168
#
# Train Epoch: 30 [10000/50000 (20.0%)]	Loss: 0.344826
#
# Train Epoch: 30 [20000/50000 (40.0%)]	Loss: 0.344191
#
# Train Epoch: 30 [30000/50000 (60.0%)]	Loss: 0.371888
#
# Train Epoch: 30 [40000/50000 (80.0%)]	Loss: 0.291697
# Train Epoch: 30  Accuracy: 43746/50000 (87.5%)
#
# Test set: Average loss: 0.5587, Accuracy: 8375/10000 (83.8%)
#
#
# Train Epoch: 31 [0/50000 (0.0%)]	Loss: 0.257519
#
# Train Epoch: 31 [10000/50000 (20.0%)]	Loss: 0.217704
#
# Train Epoch: 31 [20000/50000 (40.0%)]	Loss: 0.202493
#
# Train Epoch: 31 [30000/50000 (60.0%)]	Loss: 0.190205
#
# Train Epoch: 31 [40000/50000 (80.0%)]	Loss: 0.154152
# Train Epoch: 31  Accuracy: 45719/50000 (91.4%)
#
# Test set: Average loss: 0.3554, Accuracy: 8914/10000 (89.1%)
#
#
# Train Epoch: 32 [0/50000 (0.0%)]	Loss: 0.251081
#
# Train Epoch: 32 [10000/50000 (20.0%)]	Loss: 0.296622
#
# Train Epoch: 32 [20000/50000 (40.0%)]	Loss: 0.131173
#
# Train Epoch: 32 [30000/50000 (60.0%)]	Loss: 0.192865
#
# Train Epoch: 32 [40000/50000 (80.0%)]	Loss: 0.280525
# Train Epoch: 32  Accuracy: 46422/50000 (92.8%)
#
# Test set: Average loss: 0.3605, Accuracy: 8909/10000 (89.1%)
#
#
# Train Epoch: 33 [0/50000 (0.0%)]	Loss: 0.218496
#
# Train Epoch: 33 [10000/50000 (20.0%)]	Loss: 0.206177
#
# Train Epoch: 33 [20000/50000 (40.0%)]	Loss: 0.184222
#
# Train Epoch: 33 [30000/50000 (60.0%)]	Loss: 0.309006
#
# Train Epoch: 33 [40000/50000 (80.0%)]	Loss: 0.112572
# Train Epoch: 33  Accuracy: 46568/50000 (93.1%)
#
# Test set: Average loss: 0.3492, Accuracy: 8950/10000 (89.5%)
#
#
# Train Epoch: 34 [0/50000 (0.0%)]	Loss: 0.162324
#
# Train Epoch: 34 [10000/50000 (20.0%)]	Loss: 0.195004
#
# Train Epoch: 34 [20000/50000 (40.0%)]	Loss: 0.139347
#
# Train Epoch: 34 [30000/50000 (60.0%)]	Loss: 0.155900
#
# Train Epoch: 34 [40000/50000 (80.0%)]	Loss: 0.200855
# Train Epoch: 34  Accuracy: 46766/50000 (93.5%)
#
# Test set: Average loss: 0.3580, Accuracy: 8913/10000 (89.1%)
#
#
# Train Epoch: 35 [0/50000 (0.0%)]	Loss: 0.192010
#
# Train Epoch: 35 [10000/50000 (20.0%)]	Loss: 0.191996
#
# Train Epoch: 35 [20000/50000 (40.0%)]	Loss: 0.112890
#
# Train Epoch: 35 [30000/50000 (60.0%)]	Loss: 0.203612
#
# Train Epoch: 35 [40000/50000 (80.0%)]	Loss: 0.405592
# Train Epoch: 35  Accuracy: 46883/50000 (93.8%)
#
# Test set: Average loss: 0.3522, Accuracy: 8954/10000 (89.5%)
#
#
# Train Epoch: 36 [0/50000 (0.0%)]	Loss: 0.126007
#
# Train Epoch: 36 [10000/50000 (20.0%)]	Loss: 0.121832
#
# Train Epoch: 36 [20000/50000 (40.0%)]	Loss: 0.198764
#
# Train Epoch: 36 [30000/50000 (60.0%)]	Loss: 0.207905
#
# Train Epoch: 36 [40000/50000 (80.0%)]	Loss: 0.133867
# Train Epoch: 36  Accuracy: 46929/50000 (93.9%)
#
# Test set: Average loss: 0.3470, Accuracy: 8931/10000 (89.3%)
#
#
# Train Epoch: 37 [0/50000 (0.0%)]	Loss: 0.200639
#
# Train Epoch: 37 [10000/50000 (20.0%)]	Loss: 0.206455
#
# Train Epoch: 37 [20000/50000 (40.0%)]	Loss: 0.128304
#
# Train Epoch: 37 [30000/50000 (60.0%)]	Loss: 0.134894
#
# Train Epoch: 37 [40000/50000 (80.0%)]	Loss: 0.240365
# Train Epoch: 37  Accuracy: 47051/50000 (94.1%)
#
# Test set: Average loss: 0.3561, Accuracy: 8928/10000 (89.3%)
#
#
# Train Epoch: 38 [0/50000 (0.0%)]	Loss: 0.168423
#
# Train Epoch: 38 [10000/50000 (20.0%)]	Loss: 0.133202
#
# Train Epoch: 38 [20000/50000 (40.0%)]	Loss: 0.159321
#
# Train Epoch: 38 [30000/50000 (60.0%)]	Loss: 0.097094
#
# Train Epoch: 38 [40000/50000 (80.0%)]	Loss: 0.155711
# Train Epoch: 38  Accuracy: 47199/50000 (94.4%)
#
# Test set: Average loss: 0.3479, Accuracy: 8976/10000 (89.8%)
#
#
# Train Epoch: 39 [0/50000 (0.0%)]	Loss: 0.193967
#
# Train Epoch: 39 [10000/50000 (20.0%)]	Loss: 0.157452
#
# Train Epoch: 39 [20000/50000 (40.0%)]	Loss: 0.124242
#
# Train Epoch: 39 [30000/50000 (60.0%)]	Loss: 0.182133
#
# Train Epoch: 39 [40000/50000 (80.0%)]	Loss: 0.160240
# Train Epoch: 39  Accuracy: 47202/50000 (94.4%)
#
# Test set: Average loss: 0.3474, Accuracy: 8947/10000 (89.5%)
#
#
# Train Epoch: 40 [0/50000 (0.0%)]	Loss: 0.164906
#
# Train Epoch: 40 [10000/50000 (20.0%)]	Loss: 0.142860
#
# Train Epoch: 40 [20000/50000 (40.0%)]	Loss: 0.144471
#
# Train Epoch: 40 [30000/50000 (60.0%)]	Loss: 0.208201
#
# Train Epoch: 40 [40000/50000 (80.0%)]	Loss: 0.192334
# Train Epoch: 40  Accuracy: 47284/50000 (94.6%)
#
# Test set: Average loss: 0.3457, Accuracy: 8984/10000 (89.8%)
#
#
# Train Epoch: 41 [0/50000 (0.0%)]	Loss: 0.234093
#
# Train Epoch: 41 [10000/50000 (20.0%)]	Loss: 0.107325
#
# Train Epoch: 41 [20000/50000 (40.0%)]	Loss: 0.117165
#
# Train Epoch: 41 [30000/50000 (60.0%)]	Loss: 0.124573
#
# Train Epoch: 41 [40000/50000 (80.0%)]	Loss: 0.090101
# Train Epoch: 41  Accuracy: 47415/50000 (94.8%)
#
# Test set: Average loss: 0.3514, Accuracy: 8969/10000 (89.7%)
#
#
# Train Epoch: 42 [0/50000 (0.0%)]	Loss: 0.243679
#
# Train Epoch: 42 [10000/50000 (20.0%)]	Loss: 0.106116
#
# Train Epoch: 42 [20000/50000 (40.0%)]	Loss: 0.183579
#
# Train Epoch: 42 [30000/50000 (60.0%)]	Loss: 0.123543
#
# Train Epoch: 42 [40000/50000 (80.0%)]	Loss: 0.200026
# Train Epoch: 42  Accuracy: 47378/50000 (94.8%)
#
# Test set: Average loss: 0.3619, Accuracy: 8966/10000 (89.7%)
#
#
# Train Epoch: 43 [0/50000 (0.0%)]	Loss: 0.072301
#
# Train Epoch: 43 [10000/50000 (20.0%)]	Loss: 0.082863
#
# Train Epoch: 43 [20000/50000 (40.0%)]	Loss: 0.223925
#
# Train Epoch: 43 [30000/50000 (60.0%)]	Loss: 0.099911
#
# Train Epoch: 43 [40000/50000 (80.0%)]	Loss: 0.055025
# Train Epoch: 43  Accuracy: 47442/50000 (94.9%)
#
# Test set: Average loss: 0.3592, Accuracy: 8970/10000 (89.7%)
#
#
# Train Epoch: 44 [0/50000 (0.0%)]	Loss: 0.072182
#
# Train Epoch: 44 [10000/50000 (20.0%)]	Loss: 0.235584
#
# Train Epoch: 44 [20000/50000 (40.0%)]	Loss: 0.175596
#
# Train Epoch: 44 [30000/50000 (60.0%)]	Loss: 0.111136
#
# Train Epoch: 44 [40000/50000 (80.0%)]	Loss: 0.062493
# Train Epoch: 44  Accuracy: 47547/50000 (95.1%)
#
# Test set: Average loss: 0.3500, Accuracy: 8986/10000 (89.9%)
#
#
# Train Epoch: 45 [0/50000 (0.0%)]	Loss: 0.093460
#
# Train Epoch: 45 [10000/50000 (20.0%)]	Loss: 0.076371
#
# Train Epoch: 45 [20000/50000 (40.0%)]	Loss: 0.119841
#
# Train Epoch: 45 [30000/50000 (60.0%)]	Loss: 0.090063
#
# Train Epoch: 45 [40000/50000 (80.0%)]	Loss: 0.277904
# Train Epoch: 45  Accuracy: 47624/50000 (95.2%)
#
# Test set: Average loss: 0.3603, Accuracy: 8971/10000 (89.7%)
#
#
# Train Epoch: 46 [0/50000 (0.0%)]	Loss: 0.182161
#
# Train Epoch: 46 [10000/50000 (20.0%)]	Loss: 0.176771
#
# Train Epoch: 46 [20000/50000 (40.0%)]	Loss: 0.157504
#
# Train Epoch: 46 [30000/50000 (60.0%)]	Loss: 0.285203
#
# Train Epoch: 46 [40000/50000 (80.0%)]	Loss: 0.146100
# Train Epoch: 46  Accuracy: 47814/50000 (95.6%)
#
# Test set: Average loss: 0.3539, Accuracy: 8985/10000 (89.8%)
#
#
# Train Epoch: 47 [0/50000 (0.0%)]	Loss: 0.052063
#
# Train Epoch: 47 [10000/50000 (20.0%)]	Loss: 0.149238
#
# Train Epoch: 47 [20000/50000 (40.0%)]	Loss: 0.084719
#
# Train Epoch: 47 [30000/50000 (60.0%)]	Loss: 0.146549
#
# Train Epoch: 47 [40000/50000 (80.0%)]	Loss: 0.074256
# Train Epoch: 47  Accuracy: 47856/50000 (95.7%)
#
# Test set: Average loss: 0.3484, Accuracy: 8991/10000 (89.9%)
#
#
# Train Epoch: 48 [0/50000 (0.0%)]	Loss: 0.106264
#
# Train Epoch: 48 [10000/50000 (20.0%)]	Loss: 0.122162
#
# Train Epoch: 48 [20000/50000 (40.0%)]	Loss: 0.124744
#
# Train Epoch: 48 [30000/50000 (60.0%)]	Loss: 0.056597
#
# Train Epoch: 48 [40000/50000 (80.0%)]	Loss: 0.255316
# Train Epoch: 48  Accuracy: 47912/50000 (95.8%)
#
# Test set: Average loss: 0.3475, Accuracy: 9012/10000 (90.1%)
#
#
# Train Epoch: 49 [0/50000 (0.0%)]	Loss: 0.122806
#
# Train Epoch: 49 [10000/50000 (20.0%)]	Loss: 0.153086
#
# Train Epoch: 49 [20000/50000 (40.0%)]	Loss: 0.201017
#
# Train Epoch: 49 [30000/50000 (60.0%)]	Loss: 0.069612
#
# Train Epoch: 49 [40000/50000 (80.0%)]	Loss: 0.164258
# Train Epoch: 49  Accuracy: 47892/50000 (95.8%)
#
# Test set: Average loss: 0.3482, Accuracy: 9004/10000 (90.0%)
#
#
# Train Epoch: 50 [0/50000 (0.0%)]	Loss: 0.145170
#
# Train Epoch: 50 [10000/50000 (20.0%)]	Loss: 0.134860
#
# Train Epoch: 50 [20000/50000 (40.0%)]	Loss: 0.095933
#
# Train Epoch: 50 [30000/50000 (60.0%)]	Loss: 0.175317
#
# Train Epoch: 50 [40000/50000 (80.0%)]	Loss: 0.188107
# Train Epoch: 50  Accuracy: 47924/50000 (95.8%)
#
# Test set: Average loss: 0.3495, Accuracy: 9007/10000 (90.1%)
#
#
# Train Epoch: 51 [0/50000 (0.0%)]	Loss: 0.059492
#
# Train Epoch: 51 [10000/50000 (20.0%)]	Loss: 0.179223
#
# Train Epoch: 51 [20000/50000 (40.0%)]	Loss: 0.166465
#
# Train Epoch: 51 [30000/50000 (60.0%)]	Loss: 0.107539
#
# Train Epoch: 51 [40000/50000 (80.0%)]	Loss: 0.119872
# Train Epoch: 51  Accuracy: 48004/50000 (96.0%)
#
# Test set: Average loss: 0.3486, Accuracy: 9023/10000 (90.2%)
#
#
# Train Epoch: 52 [0/50000 (0.0%)]	Loss: 0.094229
#
# Train Epoch: 52 [10000/50000 (20.0%)]	Loss: 0.204491
#
# Train Epoch: 52 [20000/50000 (40.0%)]	Loss: 0.122713
#
# Train Epoch: 52 [30000/50000 (60.0%)]	Loss: 0.143116
#
# Train Epoch: 52 [40000/50000 (80.0%)]	Loss: 0.058654
# Train Epoch: 52  Accuracy: 47951/50000 (95.9%)
#
# Test set: Average loss: 0.3539, Accuracy: 9015/10000 (90.2%)
#
#
# Train Epoch: 53 [0/50000 (0.0%)]	Loss: 0.204827
#
# Train Epoch: 53 [10000/50000 (20.0%)]	Loss: 0.065285
#
# Train Epoch: 53 [20000/50000 (40.0%)]	Loss: 0.091613
#
# Train Epoch: 53 [30000/50000 (60.0%)]	Loss: 0.185320
#
# Train Epoch: 53 [40000/50000 (80.0%)]	Loss: 0.141974
# Train Epoch: 53  Accuracy: 47973/50000 (95.9%)
#
# Test set: Average loss: 0.3492, Accuracy: 9019/10000 (90.2%)
#
#
# Train Epoch: 54 [0/50000 (0.0%)]	Loss: 0.044130
#
# Train Epoch: 54 [10000/50000 (20.0%)]	Loss: 0.058536
#
# Train Epoch: 54 [20000/50000 (40.0%)]	Loss: 0.076793
#
# Train Epoch: 54 [30000/50000 (60.0%)]	Loss: 0.086922
#
# Train Epoch: 54 [40000/50000 (80.0%)]	Loss: 0.120587
# Train Epoch: 54  Accuracy: 47994/50000 (96.0%)
#
# Test set: Average loss: 0.3491, Accuracy: 9026/10000 (90.3%)
#
#
# Train Epoch: 55 [0/50000 (0.0%)]	Loss: 0.189660
#
# Train Epoch: 55 [10000/50000 (20.0%)]	Loss: 0.117017
#
# Train Epoch: 55 [20000/50000 (40.0%)]	Loss: 0.166411
#
# Train Epoch: 55 [30000/50000 (60.0%)]	Loss: 0.142867
#
# Train Epoch: 55 [40000/50000 (80.0%)]	Loss: 0.304017
# Train Epoch: 55  Accuracy: 48029/50000 (96.1%)
#
# Test set: Average loss: 0.3495, Accuracy: 9022/10000 (90.2%)
#
#
# Train Epoch: 56 [0/50000 (0.0%)]	Loss: 0.119127
#
# Train Epoch: 56 [10000/50000 (20.0%)]	Loss: 0.142672
#
# Train Epoch: 56 [20000/50000 (40.0%)]	Loss: 0.136752
#
# Train Epoch: 56 [30000/50000 (60.0%)]	Loss: 0.070853
#
# Train Epoch: 56 [40000/50000 (80.0%)]	Loss: 0.221081
# Train Epoch: 56  Accuracy: 47993/50000 (96.0%)
#
# Test set: Average loss: 0.3479, Accuracy: 9012/10000 (90.1%)
#
#
# Train Epoch: 57 [0/50000 (0.0%)]	Loss: 0.149343
#
# Train Epoch: 57 [10000/50000 (20.0%)]	Loss: 0.139070
#
# Train Epoch: 57 [20000/50000 (40.0%)]	Loss: 0.115055
#
# Train Epoch: 57 [30000/50000 (60.0%)]	Loss: 0.209398
#
# Train Epoch: 57 [40000/50000 (80.0%)]	Loss: 0.155674
# Train Epoch: 57  Accuracy: 48017/50000 (96.0%)
#
# Test set: Average loss: 0.3498, Accuracy: 9014/10000 (90.1%)
#
#
# Train Epoch: 58 [0/50000 (0.0%)]	Loss: 0.080823
#
# Train Epoch: 58 [10000/50000 (20.0%)]	Loss: 0.122653
#
# Train Epoch: 58 [20000/50000 (40.0%)]	Loss: 0.088501
#
# Train Epoch: 58 [30000/50000 (60.0%)]	Loss: 0.112515
#
# Train Epoch: 58 [40000/50000 (80.0%)]	Loss: 0.123234
# Train Epoch: 58  Accuracy: 48080/50000 (96.2%)
#
# Test set: Average loss: 0.3507, Accuracy: 9023/10000 (90.2%)
#
#
# Train Epoch: 59 [0/50000 (0.0%)]	Loss: 0.077655
#
# Train Epoch: 59 [10000/50000 (20.0%)]	Loss: 0.149138
#
# Train Epoch: 59 [20000/50000 (40.0%)]	Loss: 0.229965
#
# Train Epoch: 59 [30000/50000 (60.0%)]	Loss: 0.117312
#
# Train Epoch: 59 [40000/50000 (80.0%)]	Loss: 0.231512
# Train Epoch: 59  Accuracy: 48050/50000 (96.1%)
#
# Test set: Average loss: 0.3579, Accuracy: 9009/10000 (90.1%)
#
#
# Train Epoch: 60 [0/50000 (0.0%)]	Loss: 0.082178
#
# Train Epoch: 60 [10000/50000 (20.0%)]	Loss: 0.085753
#
# Train Epoch: 60 [20000/50000 (40.0%)]	Loss: 0.121797
#
# Train Epoch: 60 [30000/50000 (60.0%)]	Loss: 0.094450
#
# Train Epoch: 60 [40000/50000 (80.0%)]	Loss: 0.193959
# Train Epoch: 60  Accuracy: 48107/50000 (96.2%)
#
# Test set: Average loss: 0.3538, Accuracy: 9018/10000 (90.2%)
#
#
#  TRAIN PRUNED MODEL DONE!

# %% [markdown]
# ## 繪製Fine-tuning結果圖

# %%
#繪製Fine-tuning結果圖
plt.figure(figsize=(10, 5))
plt.plot(range(START_EPOCH, EPOCHS), train_accuracies, label='Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Fine-tuning Train Accuracy')
plt.legend()
plt.grid(True)
plt.show()
